# %%
a=1 #a value 
b=3
a+b
type(a)
# Out:
# int

# %%
s="Srini"
len(s)
# Out:
# 5

# %%
s="Srini" 
s[0]
s[-1]
s[:] #same like printing whole variable value
s[3:]
s[1:3]#upper limit is n-1
# Out:
# 'ni'

# %%
a="1234567.98"
a[3]
# Out:
# '4'

# %%
d="This is... 'ONE GOOD DAY' to live and Shine!!!"
d[11:25]
d[11:25:2]#last colon is jump characters
# Out:
# "'N ODDY"

# %%
#TUPLE

a=2,3,4,5
type(a)
#a[0]
#a[0]=1 #modification will not work in Tuple
#t=tuple(10)#int is not iterable
t=tuple("sadasdsd") #Change the string as Iterable tuple
s=(12345,1)
s
# Out:
# (12345, 1)

# %%
#RANGE, Start to end and skip as 3rd argument
t=range(1,20,1)
tuple(t)
f=tuple(range(1,20,1))
f[1:4]
#f.count(1)
f.index(10) #only first occurance is taken

f=tuple("Srini")
f
f.count('i')
f.index('i')

f=('a','b')
f
# Out:
# ('a', 'b')

# %%
a=int(input("a="))
b=int(input("b="))
print(f"sumof a+b={a+b}")
